# %% [markdown]
# ## Help

# %%
# %run supportFiles/evaluate.py
# Out:
# Usage: supportFiles/evaluate.py <MAX_NUM_FILES> <FEATURE_SET> <PCAP_SOURCE> ["KEEP"] ["SCAN_ALL"] ["SCAN_ONLY"]
# Datasets available are :
#  {0: 'AB-TRAP', 1: 'NB15', 2: 'CIC-IDS', 3: 'ToN-IoT', 4: 'BoT-IoT', 5: 'internet'}

# %% [markdown]
# ### Test conditions

# %%
TYPE_OF_TEST = "\"KEEP\" \"SCAN_ONLY\" \"undersampling\"" # \"oversampling\" \"SCAN_ALL\"
MAX_NUM_FILES = 96
CIC_FEATURES = 1
METHOD = "evaluateBinary.py" #"evaluate.py"

# %% [markdown]
# ### RUN ALL

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 0 $TYPE_OF_TEST
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 1 $TYPE_OF_TEST
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 2 $TYPE_OF_TEST
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 3 $TYPE_OF_TEST
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 4 $TYPE_OF_TEST
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 5 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# Using models with undersampled majority class
# loading models from SCAN_AB-TRAP_CIC_us
# Models fetched: ['SCAN_AB-TRAP_CIC_us_DT.joblib', 'SCAN_AB-TRAP_CIC_us_LR.joblib', 'SCAN_AB-TRAP_CIC_us_MLP.joblib', 'SCAN_AB-TRAP_CIC_us_NB.joblib', 'SCAN_AB-TRAP_CIC_us_SVM.joblib', 'SCAN_AB-TRAP_CIC_us_XGB.joblib']
# DT's index of best performance: 2
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# F1-score file for SCAN_AB-TRAP_CIC_us data set not found. Creating..
# reading file:
# Loading data set from existing file: SCAN_NB15_CIC.csv
# 2022-03-14 06:25:29
# Evaluating SCAN_AB-TRAP_CIC_us's ML models on SCAN_NB15_CIC data set
#
# DT's TN = 391, FP = 36284, FN = 1, TP = 400
# 2022-03-14 06:25:29
# ...

# %% [markdown]
# # Run Individually

# %% [markdown]
# ## Test AB-TRAP data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 0 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_AB-TRAP_CIC
# Models fetched: ['SCAN_AB-TRAP_CIC_DT.joblib', 'SCAN_AB-TRAP_CIC_LR.joblib', 'SCAN_AB-TRAP_CIC_MLP.joblib', 'SCAN_AB-TRAP_CIC_NB.joblib', 'SCAN_AB-TRAP_CIC_SVM.joblib', 'SCAN_AB-TRAP_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# DT
# F1-score file for SCAN_AB-TRAP_CIC data set not found. Creating..
# reading file:
# Loading data set from existing file: SCAN_NB15_CIC.csv
# 2022-01-14 15:40:38
# Evaluating SCAN_AB-TRAP_CIC's ML models on SCAN_NB15_CIC data set
#
# DT's scoreA = 0.554954954954955, scoreB = 0.0
# 2022-01-14 15:40:38
# F1-score for DT: Attack 0.554954954954955, Benign 0.0
#
# ...

# %% [markdown]
# ## Test UNSW-NB15 data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 1 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_NB15_CIC
# Models fetched: ['SCAN_NB15_CIC_DT.joblib', 'SCAN_NB15_CIC_LR.joblib', 'SCAN_NB15_CIC_MLP.joblib', 'SCAN_NB15_CIC_NB.joblib', 'SCAN_NB15_CIC_SVM.joblib', 'SCAN_NB15_CIC_XGB.joblib']
# DT's index of best performance: 10
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# DT
# Found F1-score file for SCAN_NB15_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-12 15:33:45
# Evaluating SCAN_NB15_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-12 15:34:04
# F1-score for DT: 0.0
#
# LR's score = 0.0
# 2022-01-12 15:34:19
# F1-score for LR: 0.0
#
# MLP's score = 0.0
# 2022-01-12 15:34:29
# ...

# %% [markdown]
# ## Test CIC-IDS data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 2 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_CIC-IDS_CIC
# Models fetched: ['SCAN_CIC-IDS_CIC_DT.joblib', 'SCAN_CIC-IDS_CIC_LR.joblib', 'SCAN_CIC-IDS_CIC_MLP.joblib', 'SCAN_CIC-IDS_CIC_NB.joblib', 'SCAN_CIC-IDS_CIC_SVM.joblib', 'SCAN_CIC-IDS_CIC_XGB.joblib']
# DT's index of best performance: 4
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_CIC-IDS_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-12 16:36:06
# Evaluating SCAN_CIC-IDS_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-12 16:36:17
# F1-score for DT: 0.0
#
# LR's score = 0.0
# 2022-01-12 16:36:26
# F1-score for LR: 0.0
#
# MLP's score = 0.0
# ...

# %% [markdown]
# ## Test CIC-ToN-IoT data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 3 $TYPE_OF_TEST
# Out:
# ToN-IoT and BoT-IoT only available in CIC dataset type
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_ToN-IoT_CIC
# Models fetched: ['SCAN_ToN-IoT_CIC_DT.joblib', 'SCAN_ToN-IoT_CIC_LR.joblib', 'SCAN_ToN-IoT_CIC_MLP.joblib', 'SCAN_ToN-IoT_CIC_NB.joblib', 'SCAN_ToN-IoT_CIC_SVM.joblib', 'SCAN_ToN-IoT_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_ToN-IoT_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-10 13:03:10
# Evaluating SCAN_ToN-IoT_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-10 13:03:21
# F1-score for DT: 0.0
#
# LR's score = 0.0
# ...

# %% [markdown]
# ## Test CIC-BoT-IoT data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 4 $TYPE_OF_TEST
# Out:
# ToN-IoT and BoT-IoT only available in CIC dataset type
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_BoT-IoT_CIC
# Models fetched: ['SCAN_BoT-IoT_CIC_DT.joblib', 'SCAN_BoT-IoT_CIC_LR.joblib', 'SCAN_BoT-IoT_CIC_MLP.joblib', 'SCAN_BoT-IoT_CIC_NB.joblib', 'SCAN_BoT-IoT_CIC_SVM.joblib', 'SCAN_BoT-IoT_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# XGB
# Found F1-score file for SCAN_BoT-IoT_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-12 17:16:21
# Evaluating SCAN_BoT-IoT_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-12 17:16:32
# F1-score for DT: 0.0
#
# LR's score = 0.0
# ...

# %% [markdown]
# ## Test internet AB-TRAP data set models for scanning attack detection on all other data sets

# %%
# %run supportFiles/$METHOD $MAX_NUM_FILES $CIC_FEATURES 5 $TYPE_OF_TEST
# Out:
# No Overwrite selected. Skipping data sets already tested
# Target Class: Scanning\Reconnaissance selected, exclude other attacks from Benign data
# loading models from SCAN_internet_CIC
# Models fetched: ['SCAN_internet_CIC_DT.joblib', 'SCAN_internet_CIC_LR.joblib', 'SCAN_internet_CIC_MLP.joblib', 'SCAN_internet_CIC_NB.joblib', 'SCAN_internet_CIC_SVM.joblib', 'SCAN_internet_CIC_XGB.joblib']
# DT's index of best performance: 5
# LR's index of best performance: 0
# MLP's index of best performance: 0
# NB's index of best performance: 0
# SVM's index of best performance: 0
# XGB's index of best performance: 0
# DT
# Found F1-score file for SCAN_internet_CIC data set
# reading file:
# Loading data set from existing file: SCAN_AB-TRAP_CIC.csv
# 2022-01-10 12:18:19
# Evaluating SCAN_internet_CIC's ML models on SCAN_AB-TRAP_CIC data set
#
# DT's score = 0.0
# 2022-01-10 12:18:30
# F1-score for DT: 0.0
#
# LR's score = 0.0
# 2022-01-10 12:18:40
# F1-score for LR: 0.0
#
# MLP's score = 0.0
# ...
